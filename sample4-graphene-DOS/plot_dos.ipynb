# %%
import numpy as np 

dos=np.loadtxt('gr.dos',skiprows=1)

import matplotlib.pyplot as plt

plt.xlim(-10,10)
plt.ylim(0,5)
plt.plot(dos[:,0],dos[:,1])
plt.title('graphene DOS')
plt.xlabel('Energy(eV)')
plt.savefig('DOS.png',dpi=600)
