# %%
import numpy as np 

dos=np.loadtxt('GaN.dos',skiprows=1)

import matplotlib.pyplot as plt

plt.xlim(8,19)
plt.ylim(0,7)
plt.plot(dos[:,0],dos[:,1])
plt.title('GaN DOS')
plt.xlabel('Energy(eV)')
plt.savefig('DOS.png',dpi=600)
